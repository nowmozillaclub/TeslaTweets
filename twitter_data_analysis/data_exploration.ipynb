# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-04fc773a-7cbb-44a4-bc17-9ed33af1913e" name="files[]" multiple disabled />
#      <output id="result-04fc773a-7cbb-44a4-bc17-9ed33af1913e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_elonmusk.csv to data_elonmusk.csv

# %%
import pandas as pd
import datetime as dt

import calendar as cal
import matplotlib.pyplot as plt
data = pd.read_csv('data_elonmusk.csv', encoding= 'unicode_escape')

# %%
import numpy as np
from collections import Counter

# %%
data.head()
# Out:
#   row ID  ...      User
# 0   Row0  ...  elonmusk
# 1   Row1  ...  elonmusk
# 2   Row2  ...  elonmusk
# 3   Row3  ...  elonmusk
# 4   Row4  ...  elonmusk
#
# [5 rows x 5 columns]

# %%
data['Time'] = pd.to_datetime(data['Time'])
data['Date'] = data['Time'].dt.date
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.head()
# Out:
#   row ID  ...       Date
# 0   Row0  ... 2017-09-29
# 1   Row1  ... 2017-09-29
# 2   Row2  ... 2017-09-29
# 3   Row3  ... 2017-09-29
# 4   Row4  ... 2017-09-29
#
# [5 rows x 6 columns]

# %%
data['month'] = data['Date'].dt.month

# %%
data.head()
# Out:
#   row ID                                              Tweet  ...       Date month
# 0   Row0  @MeltingIce Assuming max acceleration of 2 to ...  ... 2017-09-29     9
# 1   Row1  RT @SpaceX: BFR is capable of transporting sat...  ... 2017-09-29     9
# 2   Row2                                     @bigajm Yup :)  ... 2017-09-29     9
# 3   Row3                     Part 2 https://t.co/8Fvu57muhM  ... 2017-09-29     9
# 4   Row4  Fly to most places on Earth in under 30 mins a...  ... 2017-09-29     9
#
# [5 rows x 7 columns]

# %%
cal.month_name[1]
# Out:
# 'January'

# %%
 x = data.groupby(['month']).month.count()
print(x)

# %%
data.head()

# %%
my_list =x
x_arr = np.array(my_list)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])


ax.bar(x['month'],x[])
plt.show()

# %%
month_list = data['month'].to_list()
month_name = []

# %%
for m in month:
  name = cal.month_name(m)
  month_name.append(name)

# %%
data['len_of_words'] = data.Tweet.apply(lambda x: len(str(x).split()))

# %%
data['tweet_len'] = data.Tweet.apply(lambda x:len(str(x)))

# %%
data['No_of_words'] = data.Tweet.apply(lambda x: (str(x).split()))

# %%
print(data['No_of_words'])
# Out:
# 0       [@MeltingIce, Assuming, max, acceleration, of,...
# 1       [RT, @SpaceX:, BFR, is, capable, of, transport...
# 2                                      [@bigajm, Yup, :)]
# 3                      [Part, 2, https://t.co/8Fvu57muhM]
# 4       [Fly, to, most, places, on, Earth, in, under, ...
#                               ...
# 3213    [@YOUSRC, Amos's, article, was, fair,, but, hi...
# 3214    [These, articles, in, Space, News, describe, w...
# 3215    [Was, misquoted, by, BBC, as, saying, Europe's...
# 3216    [Just, returned, from, a, trip, to, London, an...
# 3217    [RT, @Jon_Favreau:, My, Model, S, just, arrive...
# Name: No_of_words, Length: 3218, dtype: object

# %%
word_count= data['No_of_words'].most_common()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-8253bd02fb19> in <module>()
# ----> 1 word_count= data['No_of_words'].most_common()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'most_common'
